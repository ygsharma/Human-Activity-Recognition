# %% [markdown]
# # HumanActivityRecognition
#
# <br>
#
#
# This project is to build a model that predicts the human activities such as Walking, Walking_Upstairs, Walking_Downstairs, Sitting, Standing or Laying.
#
# This dataset is collected from 30 persons(referred as subjects in this dataset), performing different activities with a smartphone to their waists. The data is recorded with the help of sensors (accelerometer and Gyroscope) in that smartphone. This experiment was video recorded to label the data manually.
#
# ## How data was recorded
#
# By using the sensors(Gyroscope and accelerometer) in a smartphone, they have captured '3-axial linear acceleration'(_tAcc-XYZ_) from accelerometer and '3-axial angular velocity' (_tGyro-XYZ_) from Gyroscope with several variations.
#
# > prefix 't' in those metrics denotes time.
#
# > suffix 'XYZ' represents 3-axial signals in X , Y, and Z directions.
#
# ### Feature names
#
# 1. These sensor signals are preprocessed by applying noise filters and then sampled in fixed-width windows(sliding windows) of 2.56 seconds each with 50% overlap. ie., each window has 128 readings.

# %% [markdown]
# # Quick overview of the dataset :

# %% [markdown]
# * Accelerometer and Gyroscope readings are taken from 30 volunteers(referred as subjects) while performing the following 6 Activities.
#
#     1. Walking
#     2. WalkingUpstairs
#     3. WalkingDownstairs
#     4. Standing
#     5. Sitting
#     6. Lying.
#
#
# * Readings are divided into a window of 2.56 seconds with 50% overlapping.
#
# * Accelerometer readings are divided into gravity acceleration and body acceleration readings,
#   which has x,y and z components each.
#
# * Gyroscope readings are the measure of angular velocities which has x,y and z components.
#
# * Jerk signals are calculated for BodyAcceleration readings.
#
# * Fourier Transforms are made on the above time readings to obtain frequency readings.
#
# * Now, on all the base signal readings., mean, max, mad, sma, arcoefficient, engerybands,entropy etc., are calculated for each window.
#
# * We get a feature vector of 561 features and these features are given in the dataset.
#
# * Each window of readings is a datapoint of 561 features.
#
# ## Problem Framework
#
# * 30 subjects(volunteers) data is randomly split to 70%(21) test and 30%(7) train data.
# * Each datapoint corresponds one of the 6 Activities.

# %% [markdown]
# ## Problem Statement
#
#  + Given a new datapoint we have to predict the Activity

# %%
import numpy as np
import pandas as pd

from google.colab import drive
drive.mount('/content/drive')

# get features from the file feature.txt
features = list()
with open('/content/drive/My Drive/UCI_HAR_Dataset/features.txt') as f:
  features = [line.split()[1] for line in f.readlines()]
  
print('No of features : {}'.format(len(features)))
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# No of features : 561

# %%
print(features)
# Out:
# ['tBodyAcc-mean()-X', 'tBodyAcc-mean()-Y', 'tBodyAcc-mean()-Z', 'tBodyAcc-std()-X', 'tBodyAcc-std()-Y', 'tBodyAcc-std()-Z', 'tBodyAcc-mad()-X', 'tBodyAcc-mad()-Y', 'tBodyAcc-mad()-Z', 'tBodyAcc-max()-X', 'tBodyAcc-max()-Y', 'tBodyAcc-max()-Z', 'tBodyAcc-min()-X', 'tBodyAcc-min()-Y', 'tBodyAcc-min()-Z', 'tBodyAcc-sma()', 'tBodyAcc-energy()-X', 'tBodyAcc-energy()-Y', 'tBodyAcc-energy()-Z', 'tBodyAcc-iqr()-X', 'tBodyAcc-iqr()-Y', 'tBodyAcc-iqr()-Z', 'tBodyAcc-entropy()-X', 'tBodyAcc-entropy()-Y', 'tBodyAcc-entropy()-Z', 'tBodyAcc-arCoeff()-X,1', 'tBodyAcc-arCoeff()-X,2', 'tBodyAcc-arCoeff()-X,3', 'tBodyAcc-arCoeff()-X,4', 'tBodyAcc-arCoeff()-Y,1', 'tBodyAcc-arCoeff()-Y,2', 'tBodyAcc-arCoeff()-Y,3', 'tBodyAcc-arCoeff()-Y,4', 'tBodyAcc-arCoeff()-Z,1', 'tBodyAcc-arCoeff()-Z,2', 'tBodyAcc-arCoeff()-Z,3', 'tBodyAcc-arCoeff()-Z,4', 'tBodyAcc-correlation()-X,Y', 'tBodyAcc-correlation()-X,Z', 'tBodyAcc-correlation()-Y,Z', 'tGravityAcc-mean()-X', 'tGravityAcc-mean()-Y', 'tGravityAcc-mean()-Z', 'tGravityAcc-std()-X', 'tGravityAcc-std()-Y', 'tGravityAcc-std()-Z', 'tGravityAcc-mad()-X', 'tGravityAcc-mad()-Y', 'tGravityAcc-mad()-Z', 'tGravityAcc-max()-X', 'tGravityAcc-max()-Y', 'tGravityAcc-max()-Z', 'tGravityAcc-min()-X', 'tGravityAcc-min()-Y', 'tGravityAcc-min()-Z', 'tGravityAcc-sma()', 'tGravityAcc-energy()-X', 'tGravityAcc-energy()-Y', 'tGravityAcc-energy()-Z', 'tGravityAcc-iqr()-X', 'tGravityAcc-iqr()-Y', 'tGravityAcc-iqr()-Z', 'tGravityAcc-entropy()-X', 'tGravityAcc-entropy()-Y', 'tGravityAcc-entropy()-Z', 'tGravityAcc-arCoeff()-X,1', 'tGravityAcc-arCoeff()-X,2', 'tGravityAcc-arCoeff()-X,3', 'tGravityAcc-arCoeff()-X,4', 'tGravityAcc-arCoeff()-Y,1', 'tGravityAcc-arCoeff()-Y,2', 'tGravityAcc-arCoeff()-Y,3', 'tGravityAcc-arCoeff()-Y,4', 'tGravityAcc-arCoeff()-Z,1', 'tGravityAcc-arCoeff()-Z,2', 'tGravityAcc-arCoeff()-Z,3', 'tGravityAcc-arCoeff()-Z,4', 'tGravityAcc-correlation()-X,Y', 'tGravityAcc-correlation()-X,Z', 'tGravityAcc-correlation()-Y,Z', 'tBodyAccJerk-mean()-X', 'tBodyAccJerk-mean()-Y', 'tBodyAccJerk-mean()-Z', 'tBodyAccJerk-std()-X', 'tBodyAccJerk-std()-Y', 'tBodyAccJerk-std()-Z', 'tBodyAccJerk-mad()-X', 'tBodyAccJerk-mad()-Y', 'tBodyAccJerk-mad()-Z', 'tBodyAccJerk-max()-X', 'tBodyAccJerk-max()-Y', 'tBodyAccJerk-max()-Z', 'tBodyAccJerk-min()-X', 'tBodyAccJerk-min()-Y', 'tBodyAccJerk-min()-Z', 'tBodyAccJerk-sma()', 'tBodyAccJerk-energy()-X', 'tBodyAccJerk-energy()-Y', 'tBodyAccJerk-energy()-Z', 'tBodyAccJerk-iqr()-X', 'tBodyAccJerk-iqr()-Y', 'tBodyAccJerk-iqr()-Z', 'tBodyAccJerk-entropy()-X', 'tBodyAccJerk-entropy()-Y', 'tBodyAccJerk-entropy()-Z', 'tBodyAccJerk-arCoeff()-X,1', 'tBodyAccJerk-arCoeff()-X,2', 'tBodyAccJerk-arCoeff()-X,3', 'tBodyAccJerk-arCoeff()-X,4', 'tBodyAccJerk-arCoeff()-Y,1', 'tBodyAccJerk-arCoeff()-Y,2', 'tBodyAccJerk-arCoeff()-Y,3', 'tBodyAccJerk-arCoeff()-Y,4', 'tBodyAccJerk-arCoeff()-Z,1', 'tBodyAccJerk-arCoeff()-Z,2', 'tBodyAccJerk-arCoeff()-Z,3', 'tBodyAccJerk-arCoeff()-Z,4', 'tBodyAccJerk-correlation()-X,Y', 'tBodyAccJerk-correlation()-X,Z', 'tBodyAccJerk-correlation()-Y,Z', 'tBodyGyro-mean()-X', 'tBodyGyro-mean()-Y', 'tBodyGyro-mean()-Z', 'tBodyGyro-std()-X', 'tBodyGyro-std()-Y', 'tBodyGyro-std()-Z', 'tBodyGyro-mad()-X', 'tBodyGyro-mad()-Y', 'tBodyGyro-mad()-Z', 'tBodyGyro-max()-X', 'tBodyGyro-max()-Y', 'tBodyGyro-max()-Z', 'tBodyGyro-min()-X', 'tBodyGyro-min()-Y', 'tBodyGyro-min()-Z', 'tBodyGyro-sma()', 'tBodyGyro-energy()-X', 'tBodyGyro-energy()-Y', 'tBodyGyro-energy()-Z', 'tBodyGyro-iqr()-X', 'tBodyGyro-iqr()-Y', 'tBodyGyro-iqr()-Z', 'tBodyGyro-entropy()-X', 'tBodyGyro-entropy()-Y', 'tBodyGyro-entropy()-Z', 'tBodyGyro-arCoeff()-X,1', 'tBodyGyro-arCoeff()-X,2', 'tBodyGyro-arCoeff()-X,3', 'tBodyGyro-arCoeff()-X,4', 'tBodyGyro-arCoeff()-Y,1', 'tBodyGyro-arCoeff()-Y,2', 'tBodyGyro-arCoeff()-Y,3', 'tBodyGyro-arCoeff()-Y,4', 'tBodyGyro-arCoeff()-Z,1', 'tBodyGyro-arCoeff()-Z,2', 'tBodyGyro-arCoeff()-Z,3', 'tBodyGyro-arCoeff()-Z,4', 'tBodyGyro-correlation()-X,Y', 'tBodyGyro-correlation()-X,Z', 'tBodyGyro-cor ...

# %% [markdown]
# ## Obtain the  train data

# %%
# get the data from txt files to pandas dataframe
X_train = pd.read_csv('/content/drive/My Drive/UCI_HAR_Dataset/train/X_train.txt', delim_whitespace=True, header=None)
X_train.columns = features

# add subject column to dataframe 
X_train['subject'] = pd.read_csv('/content/drive/My Drive/UCI_HAR_Dataset/train/subject_train.txt', header=None, squeeze=True)

y_train = pd.read_csv('/content/drive/My Drive/UCI_HAR_Dataset/train/y_train.txt', names=['Activity'], squeeze=True)
y_train_labels = y_train.map({1: 'WALKING', 2: 'WALKING UPSTAIRS', 3: 'WALKING DOWNSTAIRS', 4: 'SITTING', 5: 'STANDING', 6:'LAYING'})

# put all column in single dataframe
train = X_train
train['Activity'] = y_train
train['ActivityName'] = y_train_labels
train.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  ...  Activity  ActivityName
# 0           0.288585          -0.020294  ...         5      STANDING
# 1           0.278419          -0.016411  ...         5      STANDING
# 2           0.279653          -0.019467  ...         5      STANDING
# 3           0.279174          -0.026201  ...         5      STANDING
# 4           0.276629          -0.016570  ...         5      STANDING
#
# [5 rows x 564 columns]

# %%
train.shape
# Out:
# (7352, 564)

# %% [markdown]
# ## Obtain the  test data

# %%
# get the data from txt files to pandas dataframe
X_test = pd.read_csv('/content/drive/My Drive/UCI_HAR_Dataset/test/X_test.txt', delim_whitespace=True, header=None)
X_test.columns = features

# add subject column to dataframe
X_test['subject'] = pd.read_csv('/content/drive/My Drive/UCI_HAR_Dataset/test/subject_test.txt')

y_test = pd.read_csv('/content/drive/My Drive/UCI_HAR_Dataset/test/y_test.txt', names=['Activity'], squeeze=True)
y_test_labels = y_test.map({1: 'WALKING', 2: 'WALKING UPSTAIRS', 3: 'WALKING DOWNSTAIRS', 4: 'SITTING', 5: 'STANDING', 6:'LAYING' })

# put all column in a single dataframe
test = X_test
test['Activity'] = y_test
test['ActivityName'] = y_test_labels
test.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  ...  Activity  ActivityName
# 0           0.257178          -0.023285  ...         5      STANDING
# 1           0.286027          -0.013163  ...         5      STANDING
# 2           0.275485          -0.026050  ...         5      STANDING
# 3           0.270298          -0.032614  ...         5      STANDING
# 4           0.274833          -0.027848  ...         5      STANDING
#
# [5 rows x 564 columns]

# %%
test.shape
# Out:
# (2947, 564)

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## 1. Check for Duplicates

# %%
# Checking for duplicates
print('No of duplicates in train : {}'.format(sum(train.duplicated())))
print('No of duplicates in test : {}'.format(sum(test.duplicated())))
# Out:
# No of duplicates in train : 0
# No of duplicates in test : 0

# %% [markdown]
# ## 2. Checking for NaN/null values

# %%
# Checking for null
print('No of NaN/Null values in train : {}'.format(train.isnull().values.sum()))
print('No of NaN/Null values in test : {}'.format(test.isnull().values.sum()))
# Out:
# No of NaN/Null values in train : 0
# No of NaN/Null values in test : 1

# %% [markdown]
# #### Removing NaN/null values

# %%
# Finding the row in which NaN value is present
row_has_NaN = test.isnull().any(axis=1)
print(test[row_has_NaN])
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  ...  Activity      ActivityName
# 2946           0.153627          -0.018437  ...         2  WALKING UPSTAIRS
#
# [1 rows x 564 columns]

# %%
# Dropping the row which contains NaN value
test.drop(axis=0, index=2946, inplace=True)
print('No of NaN/Null values in test : {}'.format(test.isnull().values.sum()))
# Out:
# No of NaN/Null values in test : 0

# %% [markdown]
# ## 3. Check for data imbalance

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')
plt.rcParams['font.family'] = 'Dejavu Sans'

# %%
plt.figure(figsize=(16,8))
plt.title('Data provided by each user')
sns.countplot(x='subject', hue='ActivityName', data=train)
plt.show()

# %%
plt.title('No of Datapoints per Activity')
sns.countplot(x=train.ActivityName)
plt.xticks(rotation=90)
# Out:
# (array([0, 1, 2, 3, 4, 5]), <a list of 6 Text major ticklabel objects>)

# %% [markdown]
# ## 4. Changing feature names

# %%
columns = train.columns

# Removing '()' from column names
columns = columns.str.replace('[()]', '')
columns = columns.str.replace('[,]', '')
columns = columns.str.replace('[-]', '')

train.columns = columns
test.columns = columns

test.columns
# Out:
# Index(['tBodyAccmeanX', 'tBodyAccmeanY', 'tBodyAccmeanZ', 'tBodyAccstdX',
#        'tBodyAccstdY', 'tBodyAccstdZ', 'tBodyAccmadX', 'tBodyAccmadY',
#        'tBodyAccmadZ', 'tBodyAccmaxX',
#        ...
#        'angletBodyAccMeangravity', 'angletBodyAccJerkMeangravityMean',
#        'angletBodyGyroMeangravityMean', 'angletBodyGyroJerkMeangravityMean',
#        'angleXgravityMean', 'angleYgravityMean', 'angleZgravityMean',
#        'subject', 'Activity', 'ActivityName'],
#       dtype='object', length=564)

# %% [markdown]
# ## 5. Save this dataframe in a csv files

# %%
# train.to_csv('/content/drive/My Drive/UCI_HAR_Dataset/new_csv_files/train1.csv', index=False)
# test.to_csv('/content/drive/My Drive/UCI_HAR_Dataset/new_csv_files/test1.csv', index=False)

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### 1. Featuring Engineering from Domain Knowledge

# %% [markdown]
# + __Static and Dynamic Activities__
#
#     - In static activities (sit, stand, lie down) motion information will not be very useful.
# 	- In the dynamic activities (Walking, WalkingUpstairs,WalkingDownstairs) motion info will be significant.

# %% [markdown]
# ### 2. Stationary and Moving activities are completely different

# %%
sns.set_palette('Set1', desat=0.80)
facetgrid = sns.FacetGrid(train, hue='ActivityName', height=6, aspect=2)
facetgrid.map(sns.distplot, 'tBodyAccMagmean', hist=False).add_legend()

plt.annotate('Stationary Activities', xy=(-0.956,17), xytext=(-0.9,23), size=20,
             va='center', ha='left',
             arrowprops=dict(arrowstyle='simple', connectionstyle='arc3,rad=0.1'))
            
plt.annotate('Moving Activities', xy=(0,3), xytext=(0.2,9), size=20,\
             va='center',ha='left',\
             arrowprops=dict(arrowstyle='simple', connectionstyle='arc3, rad=0.1'))
plt.show()

# %%
# for plotting purposes taking datapoints of each activity to a different dataframe
df1 = train[train['Activity']==1]
df2 = train[train['Activity']==2]
df3 = train[train['Activity']==3]
df4 = train[train['Activity']==4]
df5 = train[train['Activity']==5]
df6 = train[train['Activity']==6]

plt.figure(figsize=(14,7))
plt.subplot(2,2,1)
plt.title('Stationary Activities(Zoomed in)')
sns.distplot(df4['tBodyAccMagmean'],color = 'r',hist = False, label = 'Sitting')
sns.distplot(df5['tBodyAccMagmean'],color = 'm',hist = False,label = 'Standing')
sns.distplot(df6['tBodyAccMagmean'],color = 'c',hist = False, label = 'Laying')
plt.axis([-1.01, -0.5, 0, 35])
plt.legend(loc='center')

plt.subplot(2,2,2)
plt.title('Moving Activities')
sns.distplot(df1['tBodyAccMagmean'],color = 'red',hist = False, label = 'Walking')
sns.distplot(df2['tBodyAccMagmean'],color = 'blue',hist = False,label = 'Walking Up')
sns.distplot(df3['tBodyAccMagmean'],color = 'green',hist = False, label = 'Walking down')
plt.legend(loc='center right')


plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3. Magnitude of an acceleration can saperate it well

# %%
plt.figure(figsize=(7,7))
sns.boxplot(x='ActivityName', y='tBodyAccMagmean', data=train, showfliers=False, saturation=1)
plt.ylabel('Acceleration Magnitude mean')
plt.axhline(y=-0.7, xmin=0.1, xmax=0.9, dashes=(5,5), c='g')
plt.axhline(y=-0.05, xmin=0.4, dashes=(5,5), c='m')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# __ Observations__:
# - If tAccMean is < -0.8 then the Activities are either Standing or Sitting or Laying.
# - If tAccMean is > -0.6 then the Activities are either Walking or WalkingDownstairs or WalkingUpstairs.
# - If tAccMean > 0.0 then the Activity is WalkingDownstairs.
# - We can classify 75% the Acitivity labels with some errors.

# %% [markdown]
# ### 4. Position of GravityAccelerationComponants also matters

# %%
sns.boxplot(x='ActivityName', y='angleXgravityMean', data=train)
plt.axhline(y=0.08, xmin=0.1, xmax=0.9,c='m',dashes=(5,3))
plt.title('Angle between X-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.show()

# %% [markdown]
# __ Observations__:
# * If angleX,gravityMean > 0 then Activity is Laying.
# * We can classify all datapoints belonging to Laying activity with just a single if else statement.

# %%
sns.boxplot(x='ActivityName', y='angleYgravityMean', data = train, showfliers=False)
plt.title('Angle between Y-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.axhline(y=-0.22, xmin=0.1, xmax=0.8, dashes=(5,3), c='m')
plt.show()

# %% [markdown]
# # Apply t-sne on the data

# %%
import numpy as np
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# performs t-sne with different perplexity values and their repective plots..
#  img_name_prefix='t-sne'

def perform_tsne(X_data, y_data, perplexities, n_iter=1000):
    
    for index,perplexity in enumerate(perplexities):
      # perform t-sne 
      print('\n performing t-sne with perplexity {} and with {} iterations'.format(perplexity,n_iter))
      X_reduced = TSNE(verbose=2, perplexity=perplexity).fit_transform(X_data)
      print('Done...')

      # prepare the data for seaborn
      print('Creating plot for this t-sne visualization..')
      df = pd.DataFrame({'x':X_reduced[:,0], 'y':X_reduced[:,1], 'label':y_data})

      # draw the plot in appropriate place in grid
      sns.lmplot(data=df, x='x', y='y', hue='label', fit_reg=False, size=8,
                 palette="Set1", markers=['^','v','s','o','1','2'])
      plt.title('perplexity : {} and max iter : {}'.format(perplexity,n_iter))
      # img_name = img_name_prefix + '_prep_{}_iter{}.png'.format(perplexity, n_iter)
      plt.show()
      print('Done')

# %%
X_pre_tsne = train.drop(['subject','Activity','ActivityName'], axis=1)
y_pre_tsne = train['ActivityName']
perform_tsne(X_data=X_pre_tsne, y_data=y_pre_tsne, perplexities=[2,5,10,20,50])
# Out:
#  performing t-sne with perplexity 2 and with 1000 iterations
# [t-SNE] Computing 7 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.588s...
# [t-SNE] Computed neighbors for 7352 samples in 43.441s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.635854
# [t-SNE] Computed conditional probabilities in 0.051s
# [t-SNE] Iteration 50: error = 124.8019714, gradient norm = 0.0251756 (50 iterations in 7.565s)
# [t-SNE] Iteration 100: error = 107.2079773, gradient norm = 0.0324829 (50 iterations in 3.581s)
# [t-SNE] Iteration 150: error = 100.9695358, gradient norm = 0.0200078 (50 iterations in 2.566s)
# [t-SNE] Iteration 200: error = 97.5241089, gradient norm = 0.0158607 (50 iterations in 2.475s)
# [t-SNE] Iteration 250: error = 95.1858749, gradient norm = 0.0130970 (50 iterations in 2.460s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 95.185875
# [t-SNE] Iteration 300: error = 4.1140232, gradient norm = 0.0015607 (50 iterations in 2.203s)
# [t-SNE] Iteration 350: error = 3.2070649, gradient norm = 0.0010111 (50 iterations in 2.005s)
# [t-SNE] Iteration 400: error = 2.7757373, gradient norm = 0.0007181 (50 iterations in 2.025s)
# [t-SNE] Iteration 450: error = 2.5120640, gradient norm = 0.0005705 (50 iterations in 2.071s)
# [t-SNE] Iteration 500: error = 2.3292162, gradient norm = 0.0004781 (50 iterations in 2.071s)
# [t-SNE] Iteration 550: error = 2.1912465, gradient norm = 0.0004145 (50 iterations in 2.082s)
# [t-SNE] Iteration 600: error = 2.0821481, gradient norm = 0.0003729 (50 iterations in 2.108s)
# [t-SNE] Iteration 650: error = 1.9922051, gradient norm = 0.0003329 (50 iterations in 2.128s)
# [t-SNE] Iteration 700: error = 1.9165953, gradient norm = 0.0003037 (50 iterations in 2.127s)
# [t-SNE] Iteration 750: error = 1.8516903, gradient norm = 0.0002761 (50 iterations in 2.137s)
# [t-SNE] Iteration 800: error = 1.7950349, gradient norm = 0.0002563 (50 iterations in 2.150s)
# [t-SNE] Iteration 850: error = 1.7450936, gradient norm = 0.0002380 (50 iterations in 2.148s)
# [t-SNE] Iteration 900: error = 1.7003899, gradient norm = 0.0002241 (50 iterations in 2.189s)
# [t-SNE] Iteration 950: error = 1.6602980, gradient norm = 0.0002088 (50 iterations in 2.151s)
# [t-SNE] Iteration 1000: error = 1.6238508, gradient norm = 0.0001997 (50 iterations in 2.152s)
# [t-SNE] KL divergence after 1000 iterations: 1.623851
# Done...
# Creating plot for this t-sne visualization..
# /usr/local/lib/python3.6/dist-packages/seaborn/regression.py:573: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# Done
#
#  performing t-sne with perplexity 5 and with 1000 iterations
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.602s...
# [t-SNE] Computed neighbors for 7352 samples in 43.443s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.961265
# [t-SNE] Computed conditional probabilities in 0.074s
# [t-SNE] Iteration 50: error = 113.8179855, gradient norm = 0.0267973 (50 iterations in 3.863s)
# [t-SNE] Iteration 100: error = 97.4980011, gradient norm = 0.0157606 (50 iterations in 2.377s)
# [t-SNE] Iteration 150: error = 93.0522614, gradient norm = 0.0087422 (50 iterations in 2.004s)
# [t-SNE] Iteration 200: error = 91.1140442, gradient norm = 0.0067298 (50 iterations in 2.000s)
# [t-SNE] Iteration 250: error = 89.9575958, gradient norm = 0.0060654 (50 iterations in 2.052s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 89.957596
# [t-SNE] Iteration 300: error = 3.5721445, gradient norm = 0.0014594 (50 iterations in 1.972s)
# [t-SNE] Iteration 350: error = 2.8138011, gradient norm = 0.0007533 (50 iterations in 1.976s)
# [t-SNE] Iteration 400: error = 2.4324212, gradient norm = 0.0005272 (50 iterations in 1.982s)
# [t-SNE] Iteration 450: error = 2.2137849, gradient norm = 0.0004071 (50 iterations in 1.995s)
# [t-SNE] Iteration 500: error = 2.0682507, gradient norm = 0.0003330 (50 iterations in 2.016s)
# [t-SNE] Iteration 550: error = 1.9624331, gradient norm = 0.0002814 (50 iterations in 2.029s)
# [t-SNE] Iteration 600: error = 1.8815734, gradient norm = 0.0002456 (50 iterations in 2.013s)
# [t-SNE] Iteration 650: error = 1.8165803, gradient norm = 0.0002199 (50 iterations in 2.060s)
# [t-SNE] Iteration 700: error = 1.7629297, gradient norm = 0.0001969 (50 iterations in 1.990s)
# [t-SNE] Iteration 750: error = 1.7176602, gradient norm = 0.0001790 (50 iterations in 2.002s)
# [t-SNE] Iteration 800: error = 1.6790295, gradient norm = 0.0001644 (50 iterations in 2.094s)
# [t-SNE] Iteration 850: error = 1.6452498, gradient norm = 0.0001529 (50 iterations in 2.022s)
# [t-SNE] Iteration 900: error = 1.6154565, gradient norm = 0.0001435 (50 iterations in 2.008s)
# [t-SNE] Iteration 950: error = 1.5890486, gradient norm = 0.0001351 (50 iterations in 2.005s)
# [t-SNE] Iteration 1000: error = 1.5654726, gradient norm = 0.0001242 (50 iterations in 2.007s)
# [t-SNE] KL divergence after 1000 iterations: 1.565473
# Done...
# Creating plot for this t-sne visualization..
# /usr/local/lib/python3.6/dist-packages/seaborn/regression.py:573: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# Done
#
#  performing t-sne with perplexity 10 and with 1000 iterations
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.623s...
# [t-SNE] Computed neighbors for 7352 samples in 43.794s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.133828
# [t-SNE] Computed conditional probabilities in 0.132s
# [t-SNE] Iteration 50: error = 105.2695618, gradient norm = 0.0269898 (50 iterations in 3.670s)
# [t-SNE] Iteration 100: error = 90.2601471, gradient norm = 0.0111322 (50 iterations in 2.420s)
# [t-SNE] Iteration 150: error = 87.2513809, gradient norm = 0.0071312 (50 iterations in 2.128s)
# [t-SNE] Iteration 200: error = 85.9999542, gradient norm = 0.0082650 (50 iterations in 2.117s)
# [t-SNE] Iteration 250: error = 85.2981567, gradient norm = 0.0033499 (50 iterations in 2.107s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 85.298157
# [t-SNE] Iteration 300: error = 3.1302555, gradient norm = 0.0013867 (50 iterations in 2.043s)
# [t-SNE] Iteration 350: error = 2.4869509, gradient norm = 0.0006503 (50 iterations in 1.958s)
# [t-SNE] Iteration 400: error = 2.1670260, gradient norm = 0.0004226 (50 iterations in 1.998s)
# [t-SNE] Iteration 450: error = 1.9821250, gradient norm = 0.0003136 (50 iterations in 2.012s)
# [t-SNE] Iteration 500: error = 1.8639612, gradient norm = 0.0002511 (50 iterations in 1.997s)
# [t-SNE] Iteration 550: error = 1.7806625, gradient norm = 0.0002115 (50 iterations in 1.999s)
# [t-SNE] Iteration 600: error = 1.7183330, gradient norm = 0.0001815 (50 iterations in 1.992s)
# [t-SNE] Iteration 650: error = 1.6694112, gradient norm = 0.0001602 (50 iterations in 2.003s)
# [t-SNE] Iteration 700: error = 1.6298941, gradient norm = 0.0001451 (50 iterations in 2.033s)
# [t-SNE] Iteration 750: error = 1.5973009, gradient norm = 0.0001298 (50 iterations in 2.017s)
# [t-SNE] Iteration 800: error = 1.5699310, gradient norm = 0.0001195 (50 iterations in 2.018s)
# [t-SNE] Iteration 850: error = 1.5469182, gradient norm = 0.0001127 (50 iterations in 2.032s)
# [t-SNE] Iteration 900: error = 1.5276799, gradient norm = 0.0001032 (50 iterations in 2.140s)
# [t-SNE] Iteration 950: error = 1.5106831, gradient norm = 0.0000972 (50 iterations in 2.067s)
# [t-SNE] Iteration 1000: error = 1.4956095, gradient norm = 0.0000921 (50 iterations in 2.046s)
# [t-SNE] KL divergence after 1000 iterations: 1.495610
# Done...
# Creating plot for this t-sne visualization..
# /usr/local/lib/python3.6/dist-packages/seaborn/regression.py:573: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# Done
#
#  performing t-sne with perplexity 20 and with 1000 iterations
# [t-SNE] Computing 61 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.554s...
# [t-SNE] Computed neighbors for 7352 samples in 44.367s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.274335
# [t-SNE] Computed conditional probabilities in 0.259s
# [t-SNE] Iteration 50: error = 96.7066193, gradient norm = 0.0295158 (50 iterations in 3.518s)
# [t-SNE] Iteration 100: error = 83.6199188, gradient norm = 0.0084973 (50 iterations in 2.804s)
# [t-SNE] Iteration 150: error = 81.7995605, gradient norm = 0.0036594 (50 iterations in 2.550s)
# [t-SNE] Iteration 200: error = 81.1184158, gradient norm = 0.0024381 (50 iterations in 2.623s)
# [t-SNE] Iteration 250: error = 80.7541809, gradient norm = 0.0019531 (50 iterations in 2.545s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 80.754181
# [t-SNE] Iteration 300: error = 2.7030563, gradient norm = 0.0013084 (50 iterations in 2.398s)
# [t-SNE] Iteration 350: error = 2.1674860, gradient norm = 0.0005759 (50 iterations in 2.246s)
# [t-SNE] Iteration 400: error = 1.9166145, gradient norm = 0.0003544 (50 iterations in 2.275s)
# [t-SNE] Iteration 450: error = 1.7697392, gradient norm = 0.0002494 (50 iterations in 2.301s)
# [t-SNE] Iteration 500: error = 1.6759747, gradient norm = 0.0001916 (50 iterations in 2.350s)
# [t-SNE] Iteration 550: error = 1.6115890, gradient norm = 0.0001569 (50 iterations in 2.369s)
# [t-SNE] Iteration 600: error = 1.5646200, gradient norm = 0.0001334 (50 iterations in 2.342s)
# [t-SNE] Iteration 650: error = 1.5290403, gradient norm = 0.0001169 (50 iterations in 2.369s)
# [t-SNE] Iteration 700: error = 1.5011740, gradient norm = 0.0001044 (50 iterations in 2.373s)
# [t-SNE] Iteration 750: error = 1.4787097, gradient norm = 0.0000940 (50 iterations in 2.407s)
# [t-SNE] Iteration 800: error = 1.4603417, gradient norm = 0.0000863 (50 iterations in 2.364s)
# [t-SNE] Iteration 850: error = 1.4451717, gradient norm = 0.0000811 (50 iterations in 2.418s)
# [t-SNE] Iteration 900: error = 1.4325863, gradient norm = 0.0000746 (50 iterations in 2.374s)
# [t-SNE] Iteration 950: error = 1.4221352, gradient norm = 0.0000704 (50 iterations in 2.399s)
# [t-SNE] Iteration 1000: error = 1.4130992, gradient norm = 0.0000687 (50 iterations in 2.396s)
# [t-SNE] KL divergence after 1000 iterations: 1.413099
# Done...
# Creating plot for this t-sne visualization..
# /usr/local/lib/python3.6/dist-packages/seaborn/regression.py:573: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# Done
#
#  performing t-sne with perplexity 50 and with 1000 iterations
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.623s...
# [t-SNE] Computed neighbors for 7352 samples in 45.971s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.437672
# [t-SNE] Computed conditional probabilities in 0.626s
# [t-SNE] Iteration 50: error = 86.5001221, gradient norm = 0.0206424 (50 iterations in 4.683s)
# [t-SNE] Iteration 100: error = 75.5883179, gradient norm = 0.0039958 (50 iterations in 3.812s)
# [t-SNE] Iteration 150: error = 74.6543427, gradient norm = 0.0035536 (50 iterations in 3.267s)
# [t-SNE] Iteration 200: error = 74.2989655, gradient norm = 0.0024003 (50 iterations in 3.313s)
# [t-SNE] Iteration 250: error = 74.1240768, gradient norm = 0.0012282 (50 iterations in 3.330s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 74.124077
# [t-SNE] Iteration 300: error = 2.1529360, gradient norm = 0.0011884 (50 iterations in 3.235s)
# [t-SNE] Iteration 350: error = 1.7545199, gradient norm = 0.0004846 (50 iterations in 3.088s)
# [t-SNE] Iteration 400: error = 1.5851688, gradient norm = 0.0002822 (50 iterations in 3.090s)
# [t-SNE] Iteration 450: error = 1.4914706, gradient norm = 0.0001911 (50 iterations in 3.083s)
# [t-SNE] Iteration 500: error = 1.4317415, gradient norm = 0.0001393 (50 iterations in 3.056s)
# [t-SNE] Iteration 550: error = 1.3905556, gradient norm = 0.0001127 (50 iterations in 3.089s)
# [t-SNE] Iteration 600: error = 1.3615224, gradient norm = 0.0000974 (50 iterations in 3.076s)
# [t-SNE] Iteration 650: error = 1.3406639, gradient norm = 0.0000836 (50 iterations in 3.061s)
# [t-SNE] Iteration 700: error = 1.3250716, gradient norm = 0.0000743 (50 iterations in 3.151s)
# [t-SNE] Iteration 750: error = 1.3135464, gradient norm = 0.0000724 (50 iterations in 3.069s)
# [t-SNE] Iteration 800: error = 1.3050524, gradient norm = 0.0000658 (50 iterations in 3.082s)
# [t-SNE] Iteration 850: error = 1.2978528, gradient norm = 0.0000619 (50 iterations in 3.095s)
# [t-SNE] Iteration 900: error = 1.2917161, gradient norm = 0.0000594 (50 iterations in 3.093s)
# [t-SNE] Iteration 950: error = 1.2869534, gradient norm = 0.0000595 (50 iterations in 3.054s)
# [t-SNE] Iteration 1000: error = 1.2832339, gradient norm = 0.0000547 (50 iterations in 3.039s)
# [t-SNE] KL divergence after 1000 iterations: 1.283234
# Done...
# Creating plot for this t-sne visualization..
# /usr/local/lib/python3.6/dist-packages/seaborn/regression.py:573: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# Done
